# %%
import pandas as pd
import os
import pickle
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

backtest_on = False

# %%
# Load player database
data_dir = r'/Users/joshualowe/Documents/Misc/Football_Index/00_Data/00_global_player_database/'
os.chdir(data_dir)

def load_obj(file_name):
    with open(file_name + '.pkl', 'rb') as f:
        return pickle.load(f)

df = load_obj('FI_global_player_price_data_full_prem_v1')

# %%
Lfast = 2
Lslow = 8

names_to_remove = []
for name, data in df.items(): 

    # remove items with no data
    if data.avgPrice.isna().sum() > 1:
        names_to_remove.append(name)
    
    data['fast_ewma'] = data['avgPrice'].ewm(span=Lfast).mean()
    data['slow_ewma'] = data['avgPrice'].ewm(span=Lslow).mean()
    data['EWMAC'] = data['fast_ewma'] - data['slow_ewma']
    
    # round EWMAC to 2dp
    data['EWMAC_rounded'] = data['EWMAC'].round(2)
      
        
#     plt.figure(figsize=(18,5))
#     plt.plot(data['DateTime'], data['avgPrice'])
    
#     plt.plot(data['DateTime'], data['fast_ewma'])
#     plt.plot(data['DateTime'], data['slow_ewma'])
# #     plt.plot(data['DateTime'], data['Volume']/100)
#     plt.title(name)
#     plt.legend(loc='best')
#     plt.show()

for n in names_to_remove:
    df.pop(n)

# %%
df['david-de-gea']
# Out:
#      DateTime  Volume  maxPrice  minPrice  avgPrice  fast_ewma  slow_ewma  \
# 0  2019-07-09    32.0      0.74      0.73      0.74   0.740000   0.740000
# 1  2019-07-10    19.0      0.75      0.74      0.74   0.740000   0.740000
# 2  2019-07-11    21.0      0.75      0.75      0.75   0.746923   0.744197
# 3  2019-07-12    21.0      0.75      0.75      0.75   0.749000   0.746231
# 4  2019-07-13    27.0      0.75      0.75      0.75   0.749669   0.747402
# 5  2019-07-14    25.0      0.75      0.75      0.75   0.749890   0.748143
# 6  2019-07-15    58.0      0.76      0.75      0.75   0.749963   0.748642
# 7  2019-07-16    20.0      0.75      0.74      0.75   0.749988   0.748990
# 8  2019-07-17    20.0      0.74      0.74      0.74   0.743329   0.746760
# 9  2019-07-18    17.0      0.74      0.74      0.74   0.741110   0.745125
# 10 2019-07-19    24.0      0.74      0.74      0.74   0.740370   0.743910
# 11 2019-07-20    45.0      0.74      0.73      0.74   0.740123   0.742996
# 12 2019-07-21    46.0      0.73      0.70      0.71   0.720041   0.735373
# 13 2019-07-22    30.0      0.71      0.70      0.71   0.713347   0.729562
# 14 2019-07-23    26.0      0.70      0.70      0.70   0.704449   0.722838
# 15 2019-07-24    30.0      0.71      0.70      0.70   0.701483   0.717670
# 16 2019-07-25    19.0      0.71      0.71      0.71   0.707161   0.715942
# 17 2019-07-26    65.0      0.76      0.71      0.74   0.729054   0.721347
# 18 2019-07-27    55.0      0.77      0.76      0.76   0.749685   0.730009
# 19 2019-07-28    44.0      0.78      0.77      0.78   0.769895   0.741192
# 20 2019-07-29    41.0      0.78      0.78      0.78   0.776632   0.749860
# 21 2019-07-30   299.0      0.89      0.78      0.85   0.825544   0.772202
# 22 2019-07-31    94.0      0.84      0.81      0.82   0.821848   0.782857
# 23 2019-08-01    50.0      0.82      0.81      0.81   0.813949   0.788903
# 24 2019-08-02    49.0      0.82      0.81      0.82   0.817983   0.795826
# 25 2019-08-03    26.0      0.82      0.82      0.82   0.819328   0.801206
# 26 2019-08-04    25.0      0.82      0.81      0.81   0.813109   0.803163
# 27 2019-08-05    55.0      0.82      0.80      0.81   0.811036   0.804683
# 28 2019-08-06    43.0      0.81      0.80      0.81   0.810345   0.805866
# 29 2019-08-07    38.0      0.80      0.80      0.80   0.803448   0.804561
# 30 2019-08-08    48.0      0.81      0.80      0.80   0.801149   0.803547
# 31 2019-08-09    41.0      0.81      0.80      0.80   0.800383   0.802759
# 32 2019-08-10    50.0      0.81      0.80      0.80   0.800128   0.802146
# 33 2019-08-11   115.0      0.84      0.81      0.83   0.820043   0.808337
# 34 2019-08-12     3.5      0.84      0.84      0.84   0.833348   0.815374
#
#        EWMAC  EWMAC_rounded
# 0   0.000000           0.00
# 1   0.000000           0.00
# 2   0.002726           0.00
# 3   0.002769           0.00
# 4   0.002268           0.00
# 5   0.001747           0.00
# 6   0.001322           0.00
# 7   0.000998           0.00
# 8  -0.003431          -0.00
# 9  -0.004016          -0.00
# 10 -0.003540          -0.00
# 11 -0.002873          -0.00
# 12 -0.015332          -0.02
# 13 -0.016215          -0.02
# 14 -0.018389          -0.02
# 15 -0.016187          -0.02
# 16 -0.008781          -0.01
# 17  0.007707           0.01
# 18  0.019675           0.02
# 19  0.028703           0.03
# 20  0.026772           0.03
# 21  0.053342           0.05
# 22  0.038991           0.04
# 23  0.025046           0.03
# 24  0.022157           0.02
# 25  0.018122           0.02
# 26  0.009947           0.01
# 27  0.006353           0.01
# 28  0.004480           0.00
# 29 -0.001113          -0.00
# 30 -0.002398          -0.00
# 31 -0.002376          -0.00
# 32 -0.002018          -0.00
# 33  0.011706           0.01
# 34  0.017973           0.02

# %%
spend_per_player = 50
commision        = 0.02
window           = 5

returns = []

# Position determination
for name, data in df.items(): 
    
    # add row at the start to intiate position step 1/2
    data = pd.concat([data.iloc[0:1,:], data], ignore_index=True).copy()
    
    data['volatility'] = data['avgPrice'].rolling(window).mean()
    
    data['EWMAC_%_price'] = (100/data['avgPrice']) * data['EWMAC']
    
    data['position'] = np.where(data['EWMAC_%_price'] >= 1, 'Long', "Short")
    # add row at the start to intiate position step 2/2
    data.loc[0,'position'] = 'Short'
    data.loc[0,'DateTime'] = 'Dummy Row'
    
    data['change'] = np.where(data['position'] == 'Long', 1, 0).astype(int)
    data['change'] = data['change'].diff()

    data['position_lots'] = (spend_per_player / data['avgPrice']).round(0)
    data['position_lots'] = np.where(abs(data['change'])>0, data['position_lots'], np.nan)
    data['position_lots'] =  data['position_lots'].fillna(method='ffill')

    data['position_lots'] = np.where(data['change']==-1, -data['position_lots'].shift(1),
                                     data['position_lots'])
    data['position_lots'] = np.where(abs(data['change'])>0, data['position_lots'], np.nan)
        
    
    data['position_money']       = (data['position_lots'] * data['avgPrice']) *-1
    data['transaction_costs']    = np.where(data['position_money'] > 0, data['position_lots'] *commision , 0)
    data['position_money_final'] = data['position_money'] + data['transaction_costs']
    
    
    # Close out positions to show total returns
    if backtest_on == True:
        length = data.shape[0] - 1 # loc -1 was not working
        if data.loc[length,'change'] == 1:
            data.loc[length,'position_money_final'] = 0
        if data.loc[length,'change'] == 0 and data.loc[length,'position'] == 'Long':
            data.loc[length,'position_money_final'] = -data['position_money_final'][data['position_money_final'].last_valid_index()]

    
    df[name] = data.copy()
    print(('returns over over the last 30 days: %.2f and mean volatility: %.2f  - ') % (data['position_money_final'].sum(), data['volatility'].mean()) + name)
    
    returns.append([name, data['avgPrice'].mean(), data['position_money'].abs().sum() / 2., data['transaction_costs'].sum(), 
                    data['position_money_final'].sum(), data['volatility'].mean()])


returns = pd.DataFrame(returns, columns=['player', 'avg price', 'spend', 'costs', '£ return', 'avg Volatility'])
# Out:
# returns over over the last 30 days: -47.49 and mean volatility: 2.14  - tammy-abraham
# returns over over the last 30 days: 4.46 and mean volatility: 1.16  - che-adams
# returns over over the last 30 days: 0.00 and mean volatility: 0.31  - adrien-silva
# returns over over the last 30 days: 0.00 and mean volatility: 0.34  - benik-afobe
# returns over over the last 30 days: 4.62 and mean volatility: 1.53  - sergio-aguero
# returns over over the last 30 days: -54.08 and mean volatility: 0.24  - ahmed-elmohamady
# returns over over the last 30 days: -3.21 and mean volatility: 0.91  - nathan-ak%c3%a9
# returns over over the last 30 days: -47.62 and mean volatility: 0.24  - marc-albrighton
# returns over over the last 30 days: 0.00 and mean volatility: 0.67  - toby-alderweireld
# returns over over the last 30 days: -6.12 and mean volatility: 0.48  - aleix-garc%c3%ada
# returns over over the last 30 days: 1.28 and mean volatility: 3.10  - trent-alexander-arnold
# returns over over the last 30 days: 4.83 and mean volatility: 0.95  - alisson
# returns over over the last 30 days: -49.92 and mean volatility: 1.03  - miguel-almiron
# returns over over the last 30 days: -2.13 and mean volatility: 0.69  - marcos-alonso
# returns over over the last 30 days: -54.70 and mean volatility: 0.23  - ibrahim-amadou
# returns over over the last 30 days: 0.00 and mean volatility: 0.35  - daniel-amartey
# returns over over the last 30 days: 0.00 and mean volatility: 0.40  - luke-amos
# returns over over the last 30 days: -1.64 and mean volatility: 1.16  - ethan-ampadu
# returns over over the last 30 days: -53.32 and mean volatility: 0.29  - florin-andone
# returns over over the last 30 days: 0.78 and mean volatility: 0.64  - andr%c3%a9-gomes
# returns over over the last 30 days: -41.19 and mean volatility: 0.73  - andreas-pereira
# returns over over the last 30 days: 0.00 and mean volatility: 0.71  - angelino
# returns over over the last 30 days: -60.17 and mean volatility: 0.38  - michail-antonio
# returns over over the last 30 days: -11.55 and mean volatility: 0.10  - antonio-valencia
# returns over over the last 30 days: 0.00 and mean volatility: 0.39  - stuart-armstrong
# returns over over the last 30 days: -52.56 and mean volatility: 0.38  - marko-arnautovic
# returns over over the last 30 days: 0.94 and mean volatility: 0.54  - kepa-arrizabalaga
# returns over over the last 30 days: -5.26 and mean volatility: 0.18  - harry-arter
# returns over over the last 30 days: -1.82 and mean volatility: 0.54  - daniel-arzani
# returns over over the last 30 days: -3.84 and mean volatility: 0.25  - christian-atsu
# returns over over the last 30 days: -52.59 and mean volatility: 1.63  - pierre-emerick-aubameyang
# returns over over the last 30 days: 4.83 and mean volatility: 0.35  - serge-aurier
# returns over over the last 30 days: -6.31 and mean volatility: 0.38  - charlie-austin
# returns over over the last 30 days: -55.32 and mean volatility: 0.27  - jordan-ayew
# returns over over the last 30 days: -49.79 and mean volatility: 1.01  - ayoze-perez
# returns over over the last 30 days: -49.95 and mean volatility: 0.43  - cesar-azpilicueta
# returns over over the last 30 days: -4.05 and mean volatility: 0.39  - eric-bailly
# returns over over the last 30 days: 0.00 and mean volatility: 0.27  - leighton-baines
# returns over over the last 30 days: 0.00 and mean volatility: 0.47  - tiemou%c3%a9-bakayoko
# returns over over the last 30 days: 0.00 and mean volatility: 0.27  - fabi%c3%a1n-balbuena
# returns over over the last 30 days: 0.00 and mean volatility: 0.15  - leon-balogun
# returns over over the last 30 days: 24.15 and mean volatility: 1.44  - ross-barkley
# returns over over the last 30 days: -59.69 and mean volatility: 0.36  - ashley-barnes
# returns over over the last 30 days: 0.00 and mean volatility: 0.24  - antonio-barreca
# returns over over the last 30 days: 2.88 and mean volatility: 0.98  - michy-batshuayi
# returns over over the last 30 days: 0.00 and mean volatility: 0.14  - danny-batth
# returns over over the last 30 days: -2.88 and mean volatility: 0.50  - jan-bednarek
# returns over over the last 30 days: -43.77 and mean volatility: 0.14  - asmir-begovic
# returns over over the last 30 days: -51.88 and mean volatility: 0.80  - hector-bellerin
# returns over over the last 30 days: 0.00 and mean volatility: 0.14  - yohan-benalouane
# returns over over the last 30 days: -2.82 and mean volatility: 0.70  - filip-benkovic
# returns over over the last 30 days: -1.92 and mean volatility: 0.25  - ryan-bennett
# returns over over the last 30 days: 1.43 and mean volatility: 0.36  - christian-benteke
# returns over over the last 30 days: -50.05 and mean volatility: 0.53  - bernard
# returns over over the last 30 days: -55.11 and mean volatility: 0.29  - bernardo
# returns over over the last 30 days: 1.60 and mean volatility: 2.50  - bernardo-silva
# returns over over the last 30 days: -7.40 and mean volatility: 0.27  - ryan-bertrand
# returns over over the last 30 days: -49.91 and mean volatility: 0.19  - muhamed-besic
# returns over over the last 30 days: -4.07 and mean volatility: 0.60  - philip-billing
# returns over over the last 30 days: 1.00 and mean volatility: 0.51  - yves-bissouma
# returns over over the last 30 days: -2.94 and mean volatility: 0.17  - birkir-bjarnason
# returns over over the last 30 days: -3.04 and mean volatility: 0.33  - yannick-bolasie
# returns over over the last 30 days: -56.33 and mean volatility: 0.39  - willy-boly
# returns over over the last 30 days: 0.00 and mean volatility: 0.17  - ga%c3%abtan-bong
# returns over over the last 30 days: -5.26 and mean volatility: 0.18  - artur-boruc
# returns over over the last 30 days: 5.48 and mean volatility: 0.54  - sofiane-boufal
# returns over over the last 30 days: -6.56 and mean volatility: 0.30  - robbie-brady
# returns over over the last 30 days: -9.99 and mean volatility: 0.14  - claudio-bravo
# returns over over the last 30 days: 0.13 and mean volatility: 3.32  - rhian-brewster
# returns over over the last 30 days: 0.00 and mean volatility: 0.21  - miguel-britos
# returns over over the last 30 days: -2.32 and mean volatility: 1.68  - david-brooks
# returns over over the last 30 days: -50.43 and mean volatility: 1.21  - emiliano-buendia
# returns over over the last 30 days: -6.88 and mean volatility: 0.26  - sam-byram
# returns over over the last 30 days: -7.14 and mean volatility: 0.14  - willy-caballero
# returns over over the last 30 days: -9.66 and mean volatility: 0.30  - gary-cahill
# returns over over the last 30 days: 0.00 and mean volatility: 0.93  - dominic-calvert-lewin
# returns over over the last 30 days: -3.34 and mean volatility: 0.29  - etienne-capoue
# returns over over the last 30 days: -9.36 and mean volatility: 0.15  - carlos-sanchez
# returns over over the last 30 days: -7.68 and mean volatility: 0.32  - guido-carrillo
# returns over over the last 30 days: -4.54 and mean volatility: 0.22  - tom-carroll
# returns over over the last 30 days: 0.00 and mean volatility: 0.29  - cameron-carter-vickers
# returns over over the last 30 days: -53.46 and mean volatility: 0.27  - craig-cathcart
# returns over over the last 30 days: -10.39 and mean volatility: 0.33  - ivan-cavaleiro
# returns over over the last 30 days: 0.00 and mean volatility: 0.14  - petr-cech
# returns over over the last 30 days: 1.72 and mean volatility: 0.30  - cedric-soares
# returns over over the last 30 days: 4.52 and mean volatility: 0.45  - calum-chambers
# returns over over the last 30 days: 0.00 and mean volatility: 0.71  - james-chester
# returns over over the last 30 days: -0.36 and mean volatility: 1.37  - ben-chilwell
# returns over over the last 30 days: -51.29 and mean volatility: 1.47  - tahith-chong
# returns over over the last 30 days: -50.40 and mean volatility: 1.11  - hamza-choudhury
# returns over over the last 30 days: -50.40 and mean volatility: 0.80  - andreas-christensen
# returns over over the last 30 days: 0.00 and mean volatility: 0.14  - jordy-clasie
# returns over over the last 30 days: -2.63 and mean volatility: 0.19  - tom-cleverley
# returns over over the last 30 days: -19.11 and mean volatility: 0.28  - nathaniel-clyne
# returns over over the last 30 days: -49.88 and mean volatility: 0.42  - conor-coady
# returns over over the last 30 days: -5.00 and mean volatility: 0.41  - seamus-coleman
# returns over over the last 30 days: -3.70 and mean volatility: 0.27  - jack-cork
# returns over over the last 30 days: -49.98 and mean volatility: 0.21  - aaron-cresswell
# returns over over the last 30 days: -3.70 and mean volatility: 0.26  - peter-crouch
# returns over over the last 30 days: 0.00 and mean volatility: 0.27  - cuco-martina
# returns over over the last 30 days: 9.72 and mean volatility: 1.00  - patrick-cutrone
# returns over over the last 30 days: -51.62 and mean volatility: 1.66  - dani-ceballos
# returns over over the last 30 days: 0.00 and mean volatility: 0.21  - charlie-daniels
# returns over over the last 30 days: -49.98 and mean volatility: 0.44  - danilo
# returns over over the last 30 days: 0.00 and mean volatility: 0.24  - scott-dann
# returns over over the last 30 days: -5.93 and mean volatility: 0.51  - danny-ings
# returns over over the last 30 days: -7.17 and mean volatility: 0.21  - karl-darlow
# returns over over the last 30 days: -2.64 and mean volatility: 0.38  - matteo-darmian
# returns over over the last 30 days: -60.32 and mean volatility: 0.40  - david-luiz
# returns over over the last 30 days: -3.20 and mean volatility: 0.60  - tom-davies
# returns over over the last 30 days: -3.22 and mean volatility: 0.30  - craig-dawson
# returns over over the last 30 days: -50.92 and mean volatility: 2.76  - kevin-de-bruyne
# returns over over the last 30 days: -46.40 and mean volatility: 0.77  - david-de-gea
# returns over over the last 30 days: -52.26 and mean volatility: 0.43  - troy-deeney
# returns over over the last 30 days: -49.95 and mean volatility: 0.26  - jermain-defoe
# returns over over the last 30 days: 0.00 and mean volatility: 0.21  - steven-defour
# returns over over the last 30 days: -0.78 and mean volatility: 1.88  - dele-alli
# returns over over the last 30 days: -2.00 and mean volatility: 0.49  - fabian-delph
# returns over over the last 30 days: 0.00 and mean volatility: 0.35  - mousa-dembele
# returns over over the last 30 days: 5.64 and mean volatility: 0.62  - jason-denayer
# returns over over the last 30 days: -49.84 and mean volatility: 0.56  - leander-dendoncker
# returns over over the last 30 days: 1.20 and mean volatility: 0.85  - gerard-deulofeu
# returns over over the last 30 days: -0.78 and mean volatility: 0.65  - grady-diangana
# returns over over the last 30 days: 0.00 and mean volatility: 1.26  - brahim-diaz
# returns over over the last 30 days: 0.00 and mean volatility: 0.35  - eric-dier
# returns over over the last 30 days: 1.60 and mean volatility: 1.50  - lucas-digne
# returns over over the last 30 days: -1.20 and mean volatility: 0.82  - diogo-dalot
# returns over over the last 30 days: -42.41 and mean volatility: 1.58  - diogo-jota
# returns over over the last 30 days: 0.00 and mean volatility: 0.85  - issa-diop
# returns over over the last 30 days: 0.00 and mean volatility: 0.92  - moussa-djenepo
# returns over over the last 30 days: -51.53 and mean volatility: 0.57  - matt-doherty
# returns over over the last 30 days: -1.44 and mean volatility: 0.68  - abdoulaye-doucoure
# returns over over the last 30 days: 9.05 and mean volatility: 0.78  - douglas-luiz
# returns over over the last 30 days: -4.15 and mean volatility: 0.58  - kieran-dowell
# returns over over the last 30 days: -6.25 and mean volatility: 0.34  - daniel-drinkwater
# returns over over the last 30 days: 1.11 and mean volatility: 0.44  - josip-drmic
# returns over over the last 30 days: -2.65 and mean volatility: 0.35  - martin-dubravka
# returns over over the last 30 days: -48.67 and mean volatility: 0.37  - shane-duffy
# returns over over the last 30 days: 0.00 and mean volatility: 1.26  - bobby-duncan
# returns over over the last 30 days: -50.96 and mean volatility: 0.55  - lewis-dunk
# returns over over the last 30 days: 13.89 and mean volatility: 1.50  - eddie-nketiah
# returns over over the last 30 days: 7.75 and mean volatility: 0.76  - ederson
# returns over over the last 30 days: -6.66 and mean volatility: 0.15  - robert-elliot
# returns over over the last 30 days: -54.50 and mean volatility: 0.69  - emerson
# returns over over the last 30 days: -49.95 and mean volatility: 0.37  - bj%c3%b6rn-engels
# returns over over the last 30 days: 0.57 and mean volatility: 0.88  - eric-garcia
# returns over over the last 30 days: 2.08 and mean volatility: 1.91  - christian-eriksen
# returns over over the last 30 days: -50.10 and mean volatility: 0.29  - jonny-evans
# returns over over the last 30 days: -6.95 and mean volatility: 0.29  - lukasz-fabianski
# returns over over the last 30 days: -3.92 and mean volatility: 0.62  - fabinho
# returns over over the last 30 days: -5.00 and mean volatility: 0.33  - cesc-fabregas
# returns over over the last 30 days: -49.91 and mean volatility: 0.22  - ralf-fahrmann
# returns over over the last 30 days: -16.65 and mean volatility: 0.14  - federico-fernandez
# returns over over the last 30 days: -0.36 and mean volatility: 1.39  - felipe-anderson
# returns over over the last 30 days: 0.00 and mean volatility: 0.17  - marouane-fellaini
# returns over over the last 30 days: -10.00 and mean volatility: 0.33  - edimilson-fernandes
# returns over over the last 30 days: -6.35 and mean volatility: 0.30  - fernandinho
# returns over over the last 30 days: -54.09 and mean volatility: 0.35  - john-fleck
# returns over over the last 30 days: 1.04 and mean volatility: 3.69  - phil-foden
# returns over over the last 30 days: -50.54 and mean volatility: 1.32  - pablo-fornals
# returns over over the last 30 days: -18.41 and mean volatility: 0.18  - fraser-forster
# returns over over the last 30 days: -49.92 and mean volatility: 0.25  - ben-foster
# returns over over the last 30 days: -49.92 and mean volatility: 0.39  - timothy-fosu-mensah
# returns over over the last 30 days: -0.58 and mean volatility: 0.91  - juan-foyth
# returns over over the last 30 days: 0.00 and mean volatility: 0.17  - simon-francis
# returns over over the last 30 days: -1.75 and mean volatility: 1.31  - ryan-fraser
# returns over over the last 30 days: -50.96 and mean volatility: 0.72  - fred
# returns over over the last 30 days: -4.34 and mean volatility: 0.24  - freddie-woodman
# returns over over the last 30 days: -2.78 and mean volatility: 0.38  - ryan-fredericks
# returns over over the last 30 days: -50.00 and mean volatility: 0.24  - christian-fuchs
# returns over over the last 30 days: -4.51 and mean volatility: 0.32  - manolo-gabbiadini
# returns over over the last 30 days: -50.60 and mean volatility: 2.27  - gabriel-jesus
# returns over over the last 30 days: -46.74 and mean volatility: 1.30  - gabriel-martinelli
# returns over over the last 30 days: -50.25 and mean volatility: 0.75  - conor-gallagher
# returns over over the last 30 days: -53.28 and mean volatility: 1.11  - james-garner
# returns over over the last 30 days: -8.34 and mean volatility: 0.23  - paulo-gazzaniga
# returns over over the last 30 days: 0.00 and mean volatility: 0.56  - jean-philippe-gbamin
# returns over over the last 30 days: -5.76 and mean volatility: 0.24  - rachid-ghezzal
# returns over over the last 30 days: 5.76 and mean volatility: 1.67  - morgan-gibbs-white
# returns over over the last 30 days: -5.55 and mean volatility: 0.25  - ben-gibson
# returns over over the last 30 days: 0.00 and mean volatility: 0.51  - charlie-gilmour
# returns over over the last 30 days: 0.00 and mean volatility: 0.62  - olivier-giroud
# returns over over the last 30 days: -49.80 and mean volatility: 0.83  - ben-godfrey
# returns over over the last 30 days: 0.00 and mean volatility: 0.65  - claudio-gomes
# returns over over the last 30 days: 0.00 and mean volatility: 0.24  - dan-gosling
# returns over over the last 30 days: 0.00 and mean volatility: 0.89  - demarai-gray
# returns over over the last 30 days: -49.29 and mean volatility: 2.10  - jack-grealish
# returns over over the last 30 days: -44.58 and mean volatility: 4.11  - mason-greenwood
# returns over over the last 30 days: -4.82 and mean volatility: 0.40  - pascal-gro%c3%9f
# returns over over the last 30 days: 0.00 and mean volatility: 0.67  - marko-grujic
# returns over over the last 30 days: -49.95 and mean volatility: 0.26  - vicente-guaita
# returns over over the last 30 days: -51.38 and mean volatility: 1.01  - matteo-guendouzi
# returns over over the last 30 days: -9.18 and mean volatility: 0.44  - idrissa-gueye
# returns over over the last 30 days: 23.63 and mean volatility: 0.48  - frederic-guilbert
# returns over over the last 30 days: -1.86 and mean volatility: 0.82  - ilkay-gundogan
# returns over over the last 30 days: -3.56 and mean volatility: 0.32  - angus-gunn
# returns over over the last 30 days: -7.89 and mean volatility: 0.19  - sead-haksabanovic
# returns over over the last 30 days: -48.36 and mean volatility: 1.49  - sebastien-haller
# returns over over the last 30 days: -3.27 and mean volatility: 0.44  - ethan-hamilton
# returns over over the last 30 days: 0.00 and mean volatility: 0.71  - grant-hanley
# returns over over the last 30 days: -4.00 and mean volatility: 0.24  - joe-hart
# returns over over the last 30 days: 0.00 and mean volatility: 0.33  - kortney-hause
# returns over over the last 30 days: -50.02 and mean volatility: 0.39  - isaac-hayden
# returns over over the last 30 days: 0.00 and mean volatility: 4.44  - eden-hazard
# returns over over the last 30 days: -63.26 and mean volatility: 0.28  - tom-heaton
# returns over over the last 30 days: -53.92 and mean volatility: 0.49  - helder-costa
# returns over over the last 30 days: 0.00 and mean volatility: 0.17  - tomer-hemed
# returns over over the last 30 days: -4.00 and mean volatility: 0.25  - jeff-hendrick
# returns over over the last 30 days: -17.64 and mean volatility: 0.16  - wayne-hennessey
# returns over over the last 30 days: -1.86 and mean volatility: 0.80  - onel-hernandez
# returns over over the last 30 days: -2.21 and mean volatility: 0.47  - ander-herrera
# returns over over the last 30 days: 0.00 and mean volatility: 0.14  - heurelho-gomes
# returns over over the last 30 days: -1.36 and mean volatility: 0.69  - gonzalo-higua%c3%adn
# returns over over the last 30 days: -11.57 and mean volatility: 0.21  - wesley-hoedt
# returns over over the last 30 days: -3.37 and mean volatility: 1.16  - ki-jana-hoever
# returns over over the last 30 days: -0.61 and mean volatility: 0.88  - rob-holding
# returns over over the last 30 days: -55.68 and mean volatility: 0.25  - jos%c3%a9-holebas
# returns over over the last 30 days: -5.00 and mean volatility: 0.39  - mason-holgate
# returns over over the last 30 days: -1.92 and mean volatility: 0.76  - conor-hourihane
# returns over over the last 30 days: 0.00 and mean volatility: 4.42  - callum-hudson-odoi
# returns over over the last 30 days: -1.04 and mean volatility: 0.47  - will-hughes
# returns over over the last 30 days: -2.64 and mean volatility: 0.57  - pierre-emile-h%c3%b8jbjerg
# returns over over the last 30 days: -1.28 and mean volatility: 0.38  - jordon-ibe
# returns over over the last 30 days: -1.79 and mean volatility: 0.27  - vicente-iborra
# returns over over the last 30 days: 10.44 and mean volatility: 0.47  - kelechi-iheanacho
# returns over over the last 30 days: -10.39 and mean volatility: 0.32  - isaac-success
# returns over over the last 30 days: 0.00 and mean volatility: 0.43  - isaiah-brown
# returns over over the last 30 days: -53.97 and mean volatility: 0.68  - alex-iwobi
# returns over over the last 30 days: -3.34 and mean volatility: 0.30  - jos%c3%a9-izquierdo
# returns over over the last 30 days: -9.36 and mean volatility: 0.37  - alireza-jahanbakhsh
# returns over over the last 30 days: -48.81 and mean volatility: 1.40  - reece-james
# returns over over the last 30 days: 0.00 and mean volatility: 0.18  - daryl-janmaat
# returns over over the last 30 days: -55.82 and mean volatility: 0.23  - vincent-janssen
# returns over over the last 30 days: 0.00 and mean volatility: 0.14  - mile-jedinak
# returns over over the last 30 days: 0.00 and mean volatility: 0.26  - carl-jenkinson
# returns over over the last 30 days: -4.82 and mean volatility: 0.43  - joao-moutinho
# returns over over the last 30 days: -44.31 and mean volatility: 1.79  - joe-willock
# returns over over the last 30 days: -5.88 and mean volatility: 0.17  - joel-pereira
# returns over over the last 30 days: 4.93 and mean volatility: 1.11  - joelinton
# returns over over the last 30 days: -51.89 and mean volatility: 0.28  - johann-berg-gudmundsson
# returns over over the last 30 days: -0.82 and mean volatility: 1.04  - curtis-jones
# returns over over the last 30 days: -54.92 and mean volatility: 0.40  - jonny
# returns over over the last 30 days: 0.00 and mean volatility: 1.05  - jorginho
# returns over over the last 30 days: -7.28 and mean volatility: 0.27  - joselu
# returns over over the last 30 days: -3.06 and mean volatility: 0.46  - josh-sims
# returns over over the last 30 days: -51.14 and mean volatility: 0.69  - james-justin
# returns over over the last 30 days: -10.09 and mean volatility: 0.23  - christian-kabasele
# returns over over the last 30 days: 0.00 and mean volatility: 0.17  - lovre-kalinic
# returns over over the last 30 days: -49.50 and mean volatility: 4.76  - harry-kane
# returns over over the last 30 days: -56.82 and mean volatility: 0.56  - n-golo-kant%c3%a9
# returns over over the last 30 days: 0.00 and mean volatility: 0.28  - bartosz-kapustka
# returns over over the last 30 days: 0.00 and mean volatility: 0.28  - loris-karius
# returns over over the last 30 days: 5.04 and mean volatility: 2.44  - moise-kean
# returns over over the last 30 days: -54.86 and mean volatility: 0.43  - michael-keane
# returns over over the last 30 days: -4.84 and mean volatility: 0.81  - lloyd-kelly
# returns over over the last 30 days: -5.10 and mean volatility: 0.50  - kenedy
# returns over over the last 30 days: -3.27 and mean volatility: 0.46  - jonjoe-kenny
# returns over over the last 30 days: -4.32 and mean volatility: 0.74  - ryan-kent
# returns over over the last 30 days: -5.88 and mean volatility: 0.17  - ki-sung-yueng
# returns over over the last 30 days: -54.70 and mean volatility: 0.20  - kiko-femen%c3%ada
# returns over over the last 30 days: -49.70 and mean volatility: 0.74  - joshua-king
# returns over over the last 30 days: 0.00 and mean volatility: 0.30  - ragnar-klavan
# returns over over the last 30 days: 0.00 and mean volatility: 0.91  - timm-klose
# returns over over the last 30 days: -2.70 and mean volatility: 0.36  - anthony-knockaert
# returns over over the last 30 days: -13.90 and mean volatility: 0.17  - vincent-kompany
# returns over over the last 30 days: -5.62 and mean volatility: 0.67  - ezri-konsa
# returns over over the last 30 days: -3.12 and mean volatility: 0.47  - laurent-koscielny
# returns over over the last 30 days: 0.00 and mean volatility: 0.24  - cheikhou-kouyate
# returns over over the last 30 days: -1.48 and mean volatility: 0.67  - mateo-kovacic
# returns over over the last 30 days: 0.00 and mean volatility: 0.41  - tim-krul
# returns over over the last 30 days: -49.70 and mean volatility: 1.31  - alexandre-lacazette
# returns over over the last 30 days: -2.20 and mean volatility: 0.45  - adam-lallana
# returns over over the last 30 days: 8.74 and mean volatility: 0.53  - erik-lamela
# returns over over the last 30 days: 13.42 and mean volatility: 0.89  - manuel-lanzini
# returns over over the last 30 days: 0.00 and mean volatility: 1.72  - aymeric-laporte
# returns over over the last 30 days: -2.44 and mean volatility: 0.41  - jamaal-lascelles
# returns over over the last 30 days: 0.00 and mean volatility: 0.81  - moritz-leitner
# returns over over the last 30 days: -49.91 and mean volatility: 0.23  - florian-lejeune
# returns over over the last 30 days: -1.50 and mean volatility: 0.67  - mario-lemina
# returns over over the last 30 days: -47.36 and mean volatility: 0.42  - bernd-leno
# returns over over the last 30 days: 0.00 and mean volatility: 0.22  - leo-bonatini
# returns over over the last 30 days: -4.05 and mean volatility: 0.37  - jefferson-lerma
# returns over over the last 30 days: -2.16 and mean volatility: 0.60  - adam-lewis
# returns over over the last 30 days: 0.00 and mean volatility: 0.93  - lewis-cook
# returns over over the last 30 days: 0.00 and mean volatility: 0.24  - stephan-lichtsteiner
# returns over over the last 30 days: -49.68 and mean volatility: 0.72  - victor-lindel%c3%b6f
# returns over over the last 30 days: -49.92 and mean volatility: 0.96  - jesse-lingard
# returns over over the last 30 days: -53.60 and mean volatility: 0.30  - fernando-llorente
# returns over over the last 30 days: -4.03 and mean volatility: 0.47  - hugo-lloris
# returns over over the last 30 days: 2.70 and mean volatility: 0.39  - j%c3%bcrgen-locadia
# returns over over the last 30 days: -49.28 and mean volatility: 2.20  - ruben-loftus-cheek
# returns over over the last 30 days: -50.04 and mean volatility: 0.17  - kevin-long
# returns over over the last 30 days: -0.93 and mean volatility: 1.57  - sean-longstaff
# returns over over the last 30 days: 14.85 and mean volatility: 1.38  - ademola-lookman
# returns over over the last 30 days: 0.00 and mean volatility: 0.21  - jonas-lossl
# returns over over the last 30 days: -7.90 and mean volatility: 0.31  - dejan-lovren
# returns over over the last 30 days: -50.00 and mean volatility: 0.18  - matthew-lowton
# returns over over the last 30 days: -10.85 and mean volatility: 0.23  - lucas-piazon
# returns over over the last 30 days: -1.56 and mean volatility: 1.56  - romelu-lukaku
# returns over over the last 30 days: 0.00 and mean volatility: 0.92  - dodi-lukebakio
# returns over over the last 30 days: -24.36 and mean volatility: 0.15  - matt-macey
# returns over over the last 30 days: -52.04 and mean volatility: 2.97  - james-maddison
# returns over over the last 30 days: 0.00 and mean volatility: 0.16  - gary-madine
# returns over over the last 30 days: 0.66 and mean volatility: 2.30  - harry-maguire
# returns over over the last 30 days: -50.40 and mean volatility: 0.94  - riyad-mahrez
# returns over over the last 30 days: -51.96 and mean volatility: 0.81  - ainsley-maitland-niles
# returns over over the last 30 days: -0.97 and mean volatility: 2.51  - sadio-mane
# returns over over the last 30 days: -59.39 and mean volatility: 0.25  - eliaquim-mangala
# returns over over the last 30 days: -50.00 and mean volatility: 0.19  - javier-manquillo
# returns over over the last 30 days: -21.35 and mean volatility: 0.18  - lazar-markovic
# returns over over the last 30 days: -45.48 and mean volatility: 2.35  - anthony-martial
# returns over over the last 30 days: -2.38 and mean volatility: 0.21  - emiliano-mart%c3%adnez
# returns over over the last 30 days: 0.00 and mean volatility: 0.32  - adam-masina
# returns over over the last 30 days: -5.05 and mean volatility: 0.30  - arthur-masuaku
# returns over over the last 30 days: -52.48 and mean volatility: 0.39  - juan-mata
# returns over over the last 30 days: -49.88 and mean volatility: 0.28  - nemanja-matic
# returns over over the last 30 days: -5.61 and mean volatility: 0.51  - joel-matip
# returns over over the last 30 days: -50.51 and mean volatility: 0.95  - neal-maupay
# returns over over the last 30 days: -1.14 and mean volatility: 0.42  - konstantinos-mavropanos
# returns over over the last 30 days: -49.58 and mean volatility: 1.33  - max-aarons
# returns over over the last 30 days: -50.00 and mean volatility: 0.24  - james-mcarthur
# returns over over the last 30 days: -47.64 and mean volatility: 0.69  - oliver-mcburnie
# returns over over the last 30 days: -10.32 and mean volatility: 0.28  - james-mccarthy
# returns over over the last 30 days: 0.00 and mean volatility: 0.66  - george-mceachran
# returns over over the last 30 days: -50.40 and mean volatility: 1.17  - john-mcginn
# returns over over the last 30 days: -1.28 and mean volatility: 1.52  - dwight-mcneil
# returns over over the last 30 days: -46.80 and mean volatility: 1.11  - scott-mctominay
# returns over over the last 30 days: -2.49 and mean volatility: 0.59  - zech-medley
# returns over over the last 30 days: -4.16 and mean volatility: 0.23  - ben-mee
# returns over over the last 30 days: 0.00 and mean volatility: 0.29  - nampalys-mendy
# returns over over the last 30 days: -53.28 and mean volatility: 0.46  - chris-mepham
# returns over over the last 30 days: -4.12 and mean volatility: 0.59  - max-meyer
# returns over over the last 30 days: 0.00 and mean volatility: 0.22  - simon-mignolet
# returns over over the last 30 days: -49.68 and mean volatility: 0.70  - luka-milivojevic
# returns over over the last 30 days: 0.00 and mean volatility: 0.82  - james-milner
# returns over over the last 30 days: -50.02 and mean volatility: 0.60  - yerry-mina
# returns over over the last 30 days: -51.46 and mean volatility: 0.59  - tyrone-mings
# returns over over the last 30 days: 0.00 and mean volatility: 0.25  - kevin-mirallas
# returns over over the last 30 days: -54.06 and mean volatility: 0.47  - henrikh-mkhitaryan
# returns over over the last 30 days: -2.17 and mean volatility: 0.23  - mohamed-elneny
# returns over over the last 30 days: -3.44 and mean volatility: 0.28  - mohamed-elyounoussi
# returns over over the last 30 days: -0.50 and mean volatility: 4.89  - mohamed-salah
# returns over over the last 30 days: -2.32 and mean volatility: 0.42  - nacho-monreal
# returns over over the last 30 days: -5.02 and mean volatility: 0.78  - alvaro-morata
# returns over over the last 30 days: -2.38 and mean volatility: 0.42  - alberto-moreno
# returns over over the last 30 days: 0.00 and mean volatility: 0.25  - wes-morgan
# returns over over the last 30 days: -49.40 and mean volatility: 1.27  - ravel-morrison
# returns over over the last 30 days: -3.58 and mean volatility: 0.28  - victor-moses
# returns over over the last 30 days: -51.04 and mean volatility: 2.29  - mason-mount
# returns over over the last 30 days: -2.37 and mean volatility: 0.37  - lys-mousset
# returns over over the last 30 days: -1.52 and mean volatility: 0.33  - arijanet-muric
# returns over over the last 30 days: -55.92 and mean volatility: 0.24  - jacob-murphy
# returns over over the last 30 days: -11.57 and mean volatility: 0.30  - glenn-murray
# returns over over the last 30 days: -6.83 and mean volatility: 0.36  - shkodran-mustafi
# returns over over the last 30 days: -16.82 and mean volatility: 0.31  - yoshinori-muto
# returns over over the last 30 days: 0.00 and mean volatility: 0.38  - samir-nasri
# returns over over the last 30 days: 0.00 and mean volatility: 0.20  - marc-navarro
# returns over over the last 30 days: -49.14 and mean volatility: 1.69  - tanguy-ndombele
# returns over over the last 30 days: -51.00 and mean volatility: 2.28  - reiss-nelson
# returns over over the last 30 days: 0.00 and mean volatility: 0.29  - oumar-niasse
# returns over over the last 30 days: 1.51 and mean volatility: 0.32  - georges-k%c3%a9vin-nkoudou
# returns over over the last 30 days: -6.55 and mean volatility: 0.30  - mark-noble
# returns over over the last 30 days: 0.00 and mean volatility: 0.74  - oliver-norwood
# returns over over the last 30 days: -50.14 and mean volatility: 0.46  - jack-o-connell
# returns over over the last 30 days: -8.34 and mean volatility: 0.17  - kieran-o-hara
# returns over over the last 30 days: 3.42 and mean volatility: 0.92  - michael-obafemi
# returns over over the last 30 days: -7.68 and mean volatility: 0.24  - pedro-obiang
# returns over over the last 30 days: -50.04 and mean volatility: 0.18  - angelo-ogbonna
# returns over over the last 30 days: 0.00 and mean volatility: 0.24  - stefano-okaka
# returns over over the last 30 days: 0.00 and mean volatility: 0.34  - shinji-okazaki
# returns over over the last 30 days: 0.00 and mean volatility: 0.53  - ola-aina
# returns over over the last 30 days: -8.06 and mean volatility: 0.35  - josh-onomah
# returns over over the last 30 days: 1.43 and mean volatility: 0.63  - henry-onyekuru
# returns over over the last 30 days: -45.19 and mean volatility: 1.01  - divock-origi
# returns over over the last 30 days: 0.00 and mean volatility: 0.51  - oriol-romeu
# returns over over the last 30 days: 0.00 and mean volatility: 0.23  - david-ospina
# returns over over the last 30 days: -52.16 and mean volatility: 0.48  - nicol%c3%a1s-otamendi
# returns over over the last 30 days: -49.98 and mean volatility: 0.48  - reece-oxford
# returns over over the last 30 days: -0.95 and mean volatility: 1.59  - alex-oxlade-chamberlain
# returns over over the last 30 days: 4.16 and mean volatility: 1.03  - mesut-ozil
# returns over over the last 30 days: -38.33 and mean volatility: 1.60  - troy-parrott
# returns over over the last 30 days: -3.16 and mean volatility: 0.47  - mario-pasalic
# returns over over the last 30 days: -1.72 and mean volatility: 0.29  - felix-passlack
# returns over over the last 30 days: -50.39 and mean volatility: 0.63  - pedro-neto
# returns over over the last 30 days: -5.07 and mean volatility: 0.38  - adalberto-pe%c3%b1aranda
# returns over over the last 30 days: -1.26 and mean volatility: 2.72  - nicolas-pepe
# returns over over the last 30 days: -53.00 and mean volatility: 0.49  - roberto-pereyra
# returns over over the last 30 days: -4.03 and mean volatility: 0.36  - lucas-perez
# returns over over the last 30 days: -58.46 and mean volatility: 0.35  - nathaniel-phillips
# returns over over the last 30 days: 4.17 and mean volatility: 0.57  - jordan-pickford
# returns over over the last 30 days: -54.92 and mean volatility: 0.20  - erik-pieters
# returns over over the last 30 days: 0.00 and mean volatility: 0.23  - julio-pleguezuelo
# returns over over the last 30 days: -0.84 and mean volatility: 7.26  - paul-pogba
# returns over over the last 30 days: -39.18 and mean volatility: 0.31  - nick-pope
# returns over over the last 30 days: -49.92 and mean volatility: 0.23  - davy-pr%c3%b6pper
# returns over over the last 30 days: -50.88 and mean volatility: 1.16  - teemu-pukki
# returns over over the last 30 days: 4.40 and mean volatility: 2.57  - christian-pulisic
# returns over over the last 30 days: 0.00 and mean volatility: 0.17  - jason-puncheon
# returns over over the last 30 days: 8.82 and mean volatility: 0.86  - domingos-quina
# returns over over the last 30 days: -51.38 and mean volatility: 0.41  - rafa-mir
# returns over over the last 30 days: 0.00 and mean volatility: 0.73  - rafael-camacho
# returns over over the last 30 days: -8.05 and mean volatility: 0.30  - sandro-ram%c3%adrez
# returns over over the last 30 days: 0.00 and mean volatility: 1.17  - aaron-ramsey
# returns over over the last 30 days: -49.08 and mean volatility: 4.01  - marcus-rashford
# returns over over the last 30 days: -48.65 and mean volatility: 0.72  - nathan-redmond
# returns over over the last 30 days: -8.27 and mean volatility: 0.29  - winston-reid
# returns over over the last 30 days: -51.35 and mean volatility: 0.86  - ricardo-pereira
# returns over over the last 30 days: -0.87 and mean volatility: 1.74  - declan-rice
# returns over over the last 30 days: -1.00 and mean volatility: 1.93  - richarlison
# returns over over the last 30 days: -69.97 and mean volatility: 0.24  - diego-rico
# returns over over the last 30 days: -6.08 and mean volatility: 0.25  - jairo-riedewald
# returns over over the last 30 days: -50.04 and mean volatility: 0.33  - matt-ritchie
# returns over over the last 30 days: -51.68 and mean volatility: 1.49  - roberto-firmino
# returns over over the last 30 days: 8.78 and mean volatility: 0.83  - patrick-roberts
# returns over over the last 30 days: -50.49 and mean volatility: 1.57  - andrew-robertson
# returns over over the last 30 days: -51.83 and mean volatility: 0.70  - callum-robinson
# returns over over the last 30 days: 0.00 and mean volatility: 0.17  - roderick-miranda
# returns over over the last 30 days: 1.27 and mean volatility: 0.38  - jay-rodriguez
# returns over over the last 30 days: -1.99 and mean volatility: 0.27  - marcos-rojo
# returns over over the last 30 days: -18.00 and mean volatility: 0.24  - sergio-romero
# returns over over the last 30 days: 0.00 and mean volatility: 0.40  - salomon-rondon
# returns over over the last 30 days: 0.00 and mean volatility: 0.49  - danny-rose
# returns over over the last 30 days: 4.64 and mean volatility: 0.90  - ruben-vinagre
# returns over over the last 30 days: 0.00 and mean volatility: 0.14  - john-ruddy
# returns over over the last 30 days: -50.25 and mean volatility: 0.74  - antonio-r%c3%bcdiger
# returns over over the last 30 days: -49.95 and mean volatility: 0.39  - rui-patr%c3%adcio
# returns over over the last 30 days: -49.88 and mean volatility: 0.24  - mat-ryan
# returns over over the last 30 days: -48.50 and mean volatility: 1.07  - allan-saint-maximin
# returns over over the last 30 days: -50.00 and mean volatility: 0.19  - romain-saiss
# returns over over the last 30 days: -49.65 and mean volatility: 1.79  - bukayo-saka
# returns over over the last 30 days: -49.92 and mean volatility: 0.25  - mamadou-sakho
# returns over over the last 30 days: -0.80 and mean volatility: 1.12  - william-saliba
# returns over over the last 30 days: 0.00 and mean volatility: 0.45  - philippe-sandler
# returns over over the last 30 days: 0.63 and mean volatility: 2.37  - leroy-san%c3%a9
# returns over over the last 30 days: -52.36 and mean volatility: 0.45  - fabian-sch%c3%a4r
# returns over over the last 30 days: -3.34 and mean volatility: 0.30  - jeffrey-schlupp
# returns over over the last 30 days: -53.28 and mean volatility: 0.35  - kasper-schmeichel
# returns over over the last 30 days: -49.92 and mean volatility: 0.23  - morgan-schneiderlin
# returns over over the last 30 days: -58.50 and mean volatility: 0.23  - ken-sema
# returns over over the last 30 days: -52.59 and mean volatility: 0.61  - xherdan-shaqiri
# returns over over the last 30 days: -49.88 and mean volatility: 0.56  - billy-sharp
# returns over over the last 30 days: -49.88 and mean volatility: 0.84  - luke-shaw
# returns over over the last 30 days: 8.82 and mean volatility: 0.37  - jonjo-shelvey
# returns over over the last 30 days: -3.82 and mean volatility: 0.65  - sheyi-ojo
# returns over over the last 30 days: 3.99 and mean volatility: 0.89  - gylfi-sigurdsson
# returns over over the last 30 days: 9.79 and mean volatility: 0.60  - david-silva
# returns over over the last 30 days: -49.98 and mean volatility: 0.33  - moussa-sissoko
# returns over over the last 30 days: 1.79 and mean volatility: 0.90  - oliver-skipp
# returns over over the last 30 days: 0.00 and mean volatility: 0.26  - islam-slimani
# returns over over the last 30 days: -13.61 and mean volatility: 0.29  - chris-smalling
# returns over over the last 30 days: -58.84 and mean volatility: 0.25  - adam-smith
# returns over over the last 30 days: 0.00 and mean volatility: 1.57  - emile-smith-rowe
# returns over over the last 30 days: 0.00 and mean volatility: 0.32  - robert-snodgrass
# returns over over the last 30 days: -66.26 and mean volatility: 0.30  - sokratis
# returns over over the last 30 days: -2.82 and mean volatility: 0.69  - dominic-solanke
# returns over over the last 30 days: -8.39 and mean volatility: 0.41  - solly-march
# returns over over the last 30 days: 4.62 and mean volatility: 1.55  - son-heung-min
# returns over over the last 30 days: -2.55 and mean volatility: 0.57  - elias-sorensen
# returns over over the last 30 days: -55.50 and mean volatility: 0.44  - caglar-s%c3%b6y%c3%bcnc%c3%bc
# returns over over the last 30 days: -3.34 and mean volatility: 0.30  - junior-stanislas
# returns over over the last 30 days: 0.00 and mean volatility: 0.50  - jed-steer
# returns over over the last 30 days: 0.00 and mean volatility: 0.27  - dale-stephens
# returns over over the last 30 days: -3.24 and mean volatility: 0.52  - dujon-sterling
# returns over over the last 30 days: -62.93 and mean volatility: 0.22  - steve-cook
# returns over over the last 30 days: 0.00 and mean volatility: 0.80  - enda-stevens
# returns over over the last 30 days: -50.16 and mean volatility: 1.00  - john-stones
# returns over over the last 30 days: -49.88 and mean volatility: 0.43  - daniel-sturridge
# returns over over the last 30 days: 0.00 and mean volatility: 0.51  - denis-su%c3%a1rez
# returns over over the last 30 days: 0.00 and mean volatility: 0.17  - andrew-surman
# returns over over the last 30 days: -4.08 and mean volatility: 0.48  - sam-surridge
# returns over over the last 30 days: 0.00 and mean volatility: 0.21  - markus-suttner
# returns over over the last 30 days: 5.00 and mean volatility: 0.23  - alexander-sorloth
# returns over over the last 30 days: 0.00 and mean volatility: 0.43  - matt-targett
# returns over over the last 30 days: -7.02 and mean volatility: 0.63  - james-tarkowski
# returns over over the last 30 days: 0.00 and mean volatility: 0.60  - neil-taylor
# returns over over the last 30 days: -46.55 and mean volatility: 1.84  - youri-tielemans
# returns over over the last 30 days: 0.00 and mean volatility: 0.23  - james-tomkins
# returns over over the last 30 days: -57.89 and mean volatility: 0.18  - antonio-mart%c3%adnez
# returns over over the last 30 days: -0.60 and mean volatility: 0.82  - lucas-torreira
# returns over over the last 30 days: -2.56 and mean volatility: 0.39  - tosin-adarabioyo
# returns over over the last 30 days: -12.18 and mean volatility: 0.32  - cenk-tosun
# returns over over the last 30 days: -5.59 and mean volatility: 0.43  - andros-townsend
# returns over over the last 30 days: -5.86 and mean volatility: 0.42  - adama-traor%c3%a9
# returns over over the last 30 days: -53.26 and mean volatility: 0.65  - kieran-trippier
# returns over over the last 30 days: -51.14 and mean volatility: 0.72  - leandro-trossard
# returns over over the last 30 days: 0.50 and mean volatility: 1.00  - axel-tuanzebe
# returns over over the last 30 days: -1.64 and mean volatility: 0.90  - yan-valery
# returns over over the last 30 days: 4.00 and mean volatility: 0.52  - jes%c3%bas-vallejo
# returns over over the last 30 days: -2.44 and mean volatility: 0.41  - patrick-van-aanholt
# returns over over the last 30 days: -0.31 and mean volatility: 3.00  - virgil-van-dijk
# returns over over the last 30 days: -54.30 and mean volatility: 0.68  - jamie-vardy
# returns over over the last 30 days: 0.00 and mean volatility: 0.63  - jan-vertonghen
# returns over over the last 30 days: -6.80 and mean volatility: 0.29  - jannik-vestergaard
# returns over over the last 30 days: -1.11 and mean volatility: 0.44  - nikola-vlasic
# returns over over the last 30 days: 0.00 and mean volatility: 0.24  - sam-vokes
# returns over over the last 30 days: 0.00 and mean volatility: 0.81  - mario-vrancic
# returns over over the last 30 days: -2.70 and mean volatility: 0.36  - theo-walcott
# returns over over the last 30 days: -52.83 and mean volatility: 0.48  - kyle-walker
# returns over over the last 30 days: -49.64 and mean volatility: 0.82  - kyle-walker-peters
# returns over over the last 30 days: -49.43 and mean volatility: 2.09  - aaron-wan-bissaka
# returns over over the last 30 days: -6.83 and mean volatility: 0.35  - victor-wanyama
# returns over over the last 30 days: 0.00 and mean volatility: 0.17  - stephen-ward
# returns over over the last 30 days: -1.92 and mean volatility: 0.75  - james-ward-prowse
# returns over over the last 30 days: 0.91 and mean volatility: 0.55  - adam-webster
# returns over over the last 30 days: -49.84 and mean volatility: 0.52  - danny-welbeck
# returns over over the last 30 days: 9.18 and mean volatility: 1.09  - wesley
# returns over over the last 30 days: -3.84 and mean volatility: 0.25  - ashley-westwood
# returns over over the last 30 days: 0.00 and mean volatility: 0.32  - connor-wickham
# returns over over the last 30 days: -5.50 and mean volatility: 0.54  - georginio-wijnaldum
# returns over over the last 30 days: 0.00 and mean volatility: 0.80  - wilfred-ndidi
# returns over over the last 30 days: -4.05 and mean volatility: 0.32  - jetro-willems
# returns over over the last 30 days: -48.60 and mean volatility: 0.85  - willian
# returns over over the last 30 days: -2.00 and mean volatility: 0.48  - ben-wilmot
# returns over over the last 30 days: 14.87 and mean volatility: 0.72  - jack-wilshere
# returns over over the last 30 days: -49.45 and mean volatility: 1.15  - callum-wilson
# returns over over the last 30 days: 0.00 and mean volatility: 1.32  - harry-winks
# returns over over the last 30 days: -50.05 and mean volatility: 0.37  - chris-wood
# returns over over the last 30 days: -4.20 and mean volatility: 0.74  - ben-woodburn
# returns over over the last 30 days: 0.00 and mean volatility: 0.53  - xande-silva
# returns over over the last 30 days: -52.20 and mean volatility: 0.81  - granit-xhaka
# returns over over the last 30 days: -0.85 and mean volatility: 0.59  - andriy-yarmolenko
# returns over over the last 30 days: -6.81 and mean volatility: 0.22  - deandre-yedlin
# returns over over the last 30 days: -2.64 and mean volatility: 0.37  - maya-yoshida
# returns over over the last 30 days: -6.16 and mean volatility: 0.33  - ashley-young
# returns over over the last 30 days: 0.00 and mean volatility: 0.21  - pablo-zabaleta
# returns over over the last 30 days: -4.08 and mean volatility: 2.16  - wilfried-zaha
# returns over over the last 30 days: -1.39 and mean volatility: 0.35  - davide-zappacosta
# returns over over the last 30 days: 0.00 and mean volatility: 0.27  - marvin-zeegelaar
# returns over over the last 30 days: -0.21 and mean volatility: 1.28  - oleksandr-zinchenko
# returns over over the last 30 days: 2.25 and mean volatility: 0.68  - kurt-zouma

# %%
print(returns.iloc[:,1:].sum())
sns.scatterplot(returns['£ return'], returns['costs'])
# Out:
# avg price           370.368889
# spend             32682.915000
# costs             -1337.320000
# £ return          -9044.210000
# avg Volatility      370.032000
# dtype: float64

# %%
subset = returns[returns['avg price'] > 0.8]
print(subset.iloc[:,1:].sum())
sns.scatterplot(subset['£ return'], subset['avg price'])
# Out:
# avg price          220.768889
# spend             8893.220000
# costs             -113.800000
# £ return         -2631.900000
# avg Volatility     220.584875
# dtype: float64

# %%
# walk through an example
# df['serge-aurier']

# %%
# Action Alert
buys  = []
sells = []
for name, data in df.items(): 
    # get todays row
    tmp = data[data['DateTime'] != 'Dummy Row']
    tmp['DateTime'] = pd.to_datetime(tmp['DateTime'])
    tmp['Player'] = name
    
    tmp_buys  = tmp[(tmp['DateTime'] == pd.Timestamp('today').normalize()) & (tmp['position_lots'] > 0)]
    tmp_sells = tmp[(tmp['DateTime'] == pd.Timestamp('today').normalize()) & (tmp['position_lots'] < 0)]
    
    # get todays action
    buys.append(tmp_buys[['Player', 'DateTime', 'avgPrice', 'EWMAC_%_price', 'volatility', 'position_lots']])
    sells.append(tmp_sells[['Player', 'DateTime', 'avgPrice', 'EWMAC_%_price', 'volatility', 'position_lots']])
    
buys = pd.concat(buys)
sells = pd.concat(sells)
# Out:
# /Users/joshualowe/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Users/joshualowe/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
display(buys)
display(sells)

'''
Stratergy
- Player price over £0.8    maybe this helps the short term trading strat as the cheap players are less liquid
- EWMAC_%_price over 1%     scalled to a % as the price for different players has a big range
- '''
# Out:
#               Player   DateTime  avgPrice  EWMAC_%_price  volatility  \
# 35  marko-arnautovic 2019-08-12      0.40       1.720532       0.392
# 35    craig-cathcart 2019-08-12      0.29       1.993265       0.282
# 35       shane-duffy 2019-08-12      0.41       1.133864       0.402
# 35       reece-james 2019-08-12      1.50       1.024920       1.478
# 35           willian 2019-08-12      0.90       1.529936       0.878
#
#     position_lots
# 35          125.0
# 35          172.0
# 35          122.0
# 35           33.0
# 35           56.0
#                     Player   DateTime  avgPrice  EWMAC_%_price  volatility  \
# 35           sergio-aguero 2019-08-12      1.66       0.915850       1.668
# 35  trent-alexander-arnold 2019-08-12      3.27       0.602306       3.278
# 35        andr%c3%a9-gomes 2019-08-12      0.67       0.710599       0.674
# 35        antonio-valencia 2019-08-12      0.12      -0.334014       0.126
# 35             harry-arter 2019-08-12      0.19       0.903157       0.190
# 35       christian-benteke 2019-08-12      0.40       0.977393       0.404
# 35        birkir-bjarnason 2019-08-12      0.18       0.796330       0.180
# 35           claudio-bravo 2019-08-12      0.14      -1.603736       0.148
# 35            peter-crouch 2019-08-12      0.27       0.814399       0.270
# 35              danny-ings 2019-08-12      0.57       0.889187       0.582
# 35             lucas-digne 2019-08-12      1.63       0.685346       1.632
# 35           eddie-nketiah 2019-08-12      1.50       0.852111       1.494
# 35      federico-fernandez 2019-08-12      0.14       0.169117       0.142
# 35         felipe-anderson 2019-08-12      1.46       0.463468       1.482
# 35       manolo-gabbiadini 2019-08-12      0.35       0.783502       0.350
# 35          ki-jana-hoever 2019-08-12      1.19       0.751004       1.198
# 35             will-hughes 2019-08-12      0.49       0.871093       0.492
# 35           isaac-success 2019-08-12      0.34       0.986461       0.338
# 35           joao-moutinho 2019-08-12      0.47       0.273788       0.480
# 35               joelinton 2019-08-12      1.24      -0.058754       1.312
# 35         vincent-kompany 2019-08-12      0.18       0.896525       0.180
# 35             erik-lamela 2019-08-12      0.66       0.819252       0.676
# 35         jefferson-lerma 2019-08-12      0.36       0.107807       0.364
# 35           mohamed-salah 2019-08-12      5.00       0.753317       4.998
# 35           nacho-monreal 2019-08-12      0.43       0.822113       0.428
# 35           mario-pasalic 2019-08-12      0.49       0.884395       0.490
# 35           jonjo-shelvey 2019-08-12      0.42       0.257485       0.432
# 35         virgil-van-dijk 2019-08-12      3.08       0.683990       3.078
# 35       davide-zappacosta 2019-08-12      0.37       0.824845       0.370
# 35              kurt-zouma 2019-08-12      0.74      -0.870234       0.808
#
#     position_lots
# 35          -33.0
# 35          -16.0
# 35          -78.0
# 35         -385.0
# 35         -263.0
# 35         -143.0
# 35         -294.0
# 35         -333.0
# 35         -185.0
# 35          -93.0
# 35          -32.0
# 35          -33.0
# 35         -333.0
# 35          -35.0
# 35         -147.0
# 35          -42.0
# 35         -104.0
# 35         -147.0
# 35         -116.0
# 35          -45.0
# 35         -278.0
# 35          -98.0
# 35         -135.0
# 35          -10.0
# 35         -116.0
# 35         -104.0
# 35         -147.0
# 35          -16.0
# 35         -139.0
# 35          -75.0
# '\nStratergy\n- Player price over £0.8    maybe this helps the short term trading strat as the cheap players are less liquid\n- EWMAC_%_price over 1%     scalled to a % as the price for different players has a big range\n- '

# %%
# Portfolio
portfolio = ['ravel-morrison', 'andreas-christensen', 'juan-foyth',
             'nathan-redmond', 'miguel-almiron', 'felipe-anderson',
             'alexandre-lacazette', 'andreas-pereira',
             'dani-ceballos', 'eddie-nketiah','jack-grealish',
             'ilkay-gundogan', 'richarlison', 'virgil-van-dijk',
             'harry-kane','ainsley-maitland-niles','reece-james']
cols_ = ['DateTime','Volume','avgPrice','EWMAC_%_price','position','position_lots']
portfolio_dict = dict((k, df[k].loc[30:][cols_]) for k in portfolio if k in df)

for name, data in portfolio_dict.items():
    print('---------------------------------')
    display(name)
    display(data)
    print('---------------------------------')
# Out:
# ---------------------------------
# 'ravel-morrison'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00  259.00      1.27       0.000000    Short
# 31  2019-08-08 00:00:00  227.00      1.30       1.025429     Long
# 32  2019-08-09 00:00:00   68.00      1.32       1.795338     Long
# 33  2019-08-10 00:00:00   37.00      1.33       2.054030     Long
# 34  2019-08-11 00:00:00   20.00      1.33       1.820247     Long
# 35  2019-08-12 00:00:00    1.25      1.33       1.489941     Long
#
#     position_lots
# 30            NaN
# 31           38.0
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# ---------------------------------
# ---------------------------------
# 'andreas-christensen'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00   52.00      0.81       0.834290    Short
# 31  2019-08-08 00:00:00   32.00      0.84       2.721290     Long
# 32  2019-08-09 00:00:00   23.00      0.83       2.313471     Long
# 33  2019-08-10 00:00:00   16.00      0.82       1.337145     Long
# 34  2019-08-11 00:00:00   20.00      0.83       1.403432     Long
# 35  2019-08-12 00:00:00    0.25      0.83       1.216853     Long
#
#     position_lots
# 30            NaN
# 31           60.0
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# ---------------------------------
# ---------------------------------
# 'juan-foyth'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00    26.0      0.89       0.758566    Short
# 31  2019-08-08 00:00:00    17.0      0.90       1.233516     Long
# 32  2019-08-09 00:00:00    24.0      0.89       0.689957    Short
# 33  2019-08-10 00:00:00    17.0      0.89       0.443213    Short
# 34  2019-08-11 00:00:00    25.0      0.89       0.313574    Short
# 35  2019-08-12 00:00:00     0.5      0.89       0.233504    Short
#
#     position_lots
# 30            NaN
# 31           56.0
# 32          -56.0
# 33            NaN
# 34            NaN
# 35            NaN
# ---------------------------------
# ---------------------------------
# 'nathan-redmond'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00    24.0      0.75       0.237408    Short
# 31  2019-08-08 00:00:00    70.0      0.77       1.312745     Long
# 32  2019-08-09 00:00:00    79.0      0.81       3.523954     Long
# 33  2019-08-10 00:00:00    68.0      0.82       4.089968     Long
# 34  2019-08-11 00:00:00    53.0      0.79       2.092532     Long
# 35  2019-08-12 00:00:00     2.5      0.79       1.224389     Long
#
#     position_lots
# 30            NaN
# 31           65.0
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# ---------------------------------
# ---------------------------------
# 'miguel-almiron'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00    39.0      1.02       0.425985    Short
# 31  2019-08-08 00:00:00    50.0      1.04       1.321857     Long
# 32  2019-08-09 00:00:00    36.0      1.04       1.360346     Long
# 33  2019-08-10 00:00:00    56.0      1.08       2.771350     Long
# 34  2019-08-11 00:00:00   189.0      1.12       4.228883     Long
# 35  2019-08-12 00:00:00     3.0      1.11       3.641552     Long
#
#     position_lots
# 30            NaN
# 31           48.0
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# ---------------------------------
# ---------------------------------
# 'felipe-anderson'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00    50.0      1.41       0.198444    Short
# 31  2019-08-08 00:00:00   153.0      1.44       1.065579     Long
# 32  2019-08-09 00:00:00   316.0      1.54       3.945475     Long
# 33  2019-08-10 00:00:00   280.0      1.51       3.324451     Long
# 34  2019-08-11 00:00:00    86.0      1.46       1.219394     Long
# 35  2019-08-12 00:00:00     3.0      1.46       0.463468    Short
#
#     position_lots
# 30            NaN
# 31           35.0
# 32            NaN
# 33            NaN
# 34            NaN
# 35          -35.0
# ---------------------------------
# ---------------------------------
# 'alexandre-lacazette'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00   72.00      1.37       1.093157     Long
# 31  2019-08-08 00:00:00  147.00      1.38       1.278021     Long
# 32  2019-08-09 00:00:00  156.00      1.39       1.450116     Long
# 33  2019-08-10 00:00:00  218.00      1.41       1.894391     Long
# 34  2019-08-11 00:00:00  251.00      1.42       2.034953     Long
# 35  2019-08-12 00:00:00    8.75      1.41       1.470734     Long
#
#     position_lots
# 30           36.0
# 31            NaN
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# ---------------------------------
# ---------------------------------
# 'andreas-pereira'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00    24.0      0.76      -0.371282    Short
# 31  2019-08-08 00:00:00    59.0      0.79       1.388567     Long
# 32  2019-08-09 00:00:00    35.0      0.80       2.170394     Long
# 33  2019-08-10 00:00:00    22.0      0.80       2.055976     Long
# 34  2019-08-11 00:00:00   489.0      0.92       7.293648     Long
# 35  2019-08-12 00:00:00     7.0      0.91       7.235968     Long
#
#     position_lots
# 30            NaN
# 31           63.0
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# ---------------------------------
# ---------------------------------
# 'dani-ceballos'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00   129.0      1.67      -0.375398    Short
# 31  2019-08-08 00:00:00   134.0      1.67      -0.290001    Short
# 32  2019-08-09 00:00:00   142.0      1.71       0.819841    Short
# 33  2019-08-10 00:00:00   138.0      1.74       1.733538     Long
# 34  2019-08-11 00:00:00   239.0      1.75       1.961347     Long
# 35  2019-08-12 00:00:00     5.5      1.74       1.486918     Long
#
#     position_lots
# 30            NaN
# 31            NaN
# 32            NaN
# 33           29.0
# 34            NaN
# 35            NaN
# ---------------------------------
# ---------------------------------
# 'eddie-nketiah'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00  314.00      1.40      -4.572604    Short
# 31  2019-08-08 00:00:00  517.00      1.44      -2.301874    Short
# 32  2019-08-09 00:00:00  275.00      1.50       0.428661    Short
# 33  2019-08-10 00:00:00  133.00      1.52       1.620067     Long
# 34  2019-08-11 00:00:00  179.00      1.51       1.407242     Long
# 35  2019-08-12 00:00:00    4.25      1.50       0.852111    Short
#
#     position_lots
# 30            NaN
# 31            NaN
# 32            NaN
# 33           33.0
# 34            NaN
# 35          -33.0
# ---------------------------------
# ---------------------------------
# 'jack-grealish'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00   215.0      2.13      -0.034659    Short
# 31  2019-08-08 00:00:00   311.0      2.14       0.106429    Short
# 32  2019-08-09 00:00:00   347.0      2.18       0.940221    Short
# 33  2019-08-10 00:00:00   513.0      2.23       1.991136     Long
# 34  2019-08-11 00:00:00   248.0      2.22       1.782732     Long
# 35  2019-08-12 00:00:00     5.0      2.21       1.267764     Long
#
#     position_lots
# 30            NaN
# 31            NaN
# 32            NaN
# 33           22.0
# 34            NaN
# 35            NaN
# ---------------------------------
# ---------------------------------
# 'ilkay-gundogan'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00   15.00      0.77      -2.029400    Short
# 31  2019-08-08 00:00:00   39.00      0.79      -0.670383    Short
# 32  2019-08-09 00:00:00   28.00      0.81       0.870898    Short
# 33  2019-08-10 00:00:00   15.00      0.81       1.137128     Long
# 34  2019-08-11 00:00:00   10.00      0.80       0.495128    Short
# 35  2019-08-12 00:00:00    0.75      0.80       0.251643    Short
#
#     position_lots
# 30            NaN
# 31            NaN
# 32            NaN
# 33           62.0
# 34          -62.0
# 35            NaN
# ---------------------------------
# ---------------------------------
# 'richarlison'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00  219.00      1.99       1.469800     Long
# 31  2019-08-08 00:00:00  192.00      1.99       1.240533     Long
# 32  2019-08-09 00:00:00  173.00      1.99       0.997269    Short
# 33  2019-08-10 00:00:00  236.00      2.01       1.220784     Long
# 34  2019-08-11 00:00:00  123.00      1.99       0.664843    Short
# 35  2019-08-12 00:00:00    4.25      1.98       0.196694    Short
#
#     position_lots
# 30            NaN
# 31            NaN
# 32          -25.0
# 33           25.0
# 34          -25.0
# 35            NaN
# ---------------------------------
# ---------------------------------
# 'virgil-van-dijk'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00   307.0      3.02       0.005276    Short
# 31  2019-08-08 00:00:00   386.0      3.02       0.047670    Short
# 32  2019-08-09 00:00:00  1031.0      3.09       1.057097     Long
# 33  2019-08-10 00:00:00   410.0      3.10       1.302029     Long
# 34  2019-08-11 00:00:00   336.0      3.10       1.173489     Long
# 35  2019-08-12 00:00:00    14.5      3.08       0.683990    Short
#
#     position_lots
# 30            NaN
# 31            NaN
# 32           16.0
# 33            NaN
# 34            NaN
# 35          -16.0
# ---------------------------------
# ---------------------------------
# 'harry-kane'
#                DateTime   Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00   726.00      4.80      -0.036129    Short
# 31  2019-08-08 00:00:00  1136.00      4.80      -0.037624    Short
# 32  2019-08-09 00:00:00  1286.00      4.79      -0.125275    Short
# 33  2019-08-10 00:00:00  2351.00      4.87       0.602713    Short
# 34  2019-08-11 00:00:00  1104.00      4.95       1.408490     Long
# 35  2019-08-12 00:00:00    31.75      4.95       1.411223     Long
#
#     position_lots
# 30            NaN
# 31            NaN
# 32            NaN
# 33            NaN
# 34           10.0
# 35            NaN
# ---------------------------------
# ---------------------------------
# 'ainsley-maitland-niles'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00    22.0      0.80      -1.281884    Short
# 31  2019-08-08 00:00:00    21.0      0.80      -1.260697    Short
# 32  2019-08-09 00:00:00    24.0      0.80      -1.068388    Short
# 33  2019-08-10 00:00:00    36.0      0.81      -0.300973    Short
# 34  2019-08-11 00:00:00   263.0      0.88       3.479003     Long
# 35  2019-08-12 00:00:00     5.0      0.91       5.272577     Long
#
#     position_lots
# 30            NaN
# 31            NaN
# 32            NaN
# 33            NaN
# 34           57.0
# 35            NaN
# ---------------------------------
# ---------------------------------
# 'reece-james'
#                DateTime  Volume  avgPrice  EWMAC_%_price position  \
# 30  2019-08-07 00:00:00   89.00      1.48       1.100385     Long
# 31  2019-08-08 00:00:00  101.00      1.47       0.528933    Short
# 32  2019-08-09 00:00:00   47.00      1.47       0.300469    Short
# 33  2019-08-10 00:00:00   34.00      1.47       0.196718    Short
# 34  2019-08-11 00:00:00  144.00      1.48       0.439994    Short
# 35  2019-08-12 00:00:00    3.75      1.50       1.024920     Long
#
#     position_lots
# 30            NaN
# 31          -35.0
# 32            NaN
# 33            NaN
# 34            NaN
# 35           33.0
# ---------------------------------

# %%
df['juan-foyth']
# Out:
#                DateTime  Volume  maxPrice  minPrice  avgPrice  fast_ewma  \
# 0             Dummy Row    32.0      0.88      0.87      0.87   0.870000
# 1   2019-07-09 00:00:00    32.0      0.88      0.87      0.87   0.870000
# 2   2019-07-10 00:00:00    27.0      0.88      0.87      0.88   0.877500
# 3   2019-07-11 00:00:00    15.0      0.88      0.88      0.88   0.879231
# 4   2019-07-12 00:00:00     7.0      0.88      0.88      0.88   0.879750
# 5   2019-07-13 00:00:00    17.0      0.88      0.88      0.88   0.879917
# 6   2019-07-14 00:00:00    14.0      0.88      0.88      0.88   0.879973
# 7   2019-07-15 00:00:00    18.0      0.89      0.87      0.88   0.879991
# 8   2019-07-16 00:00:00   106.0      0.93      0.89      0.91   0.900000
# 9   2019-07-17 00:00:00    69.0      0.95      0.92      0.93   0.920001
# 10  2019-07-18 00:00:00    42.0      0.96      0.95      0.95   0.940001
# 11  2019-07-19 00:00:00    36.0      0.96      0.95      0.96   0.953334
# 12  2019-07-20 00:00:00    22.0      0.96      0.96      0.96   0.957778
# 13  2019-07-21 00:00:00    23.0      0.96      0.95      0.95   0.952593
# 14  2019-07-22 00:00:00    29.0      0.96      0.95      0.95   0.950864
# 15  2019-07-23 00:00:00    22.0      0.95      0.95      0.95   0.950288
# 16  2019-07-24 00:00:00    22.0      0.95      0.94      0.95   0.950096
# 17  2019-07-25 00:00:00    30.0      0.95      0.94      0.94   0.943365
# 18  2019-07-26 00:00:00    27.0      0.94      0.94      0.94   0.941122
# 19  2019-07-27 00:00:00    30.0      0.94      0.93      0.94   0.940374
# 20  2019-07-28 00:00:00    17.0      0.93      0.93      0.93   0.933458
# 21  2019-07-29 00:00:00    19.0      0.93      0.93      0.93   0.931153
# 22  2019-07-30 00:00:00    49.0      0.95      0.93      0.95   0.943718
# 23  2019-07-31 00:00:00   221.0      0.95      0.78      0.85   0.881239
# 24  2019-08-01 00:00:00    43.0      0.86      0.84      0.85   0.860413
# 25  2019-08-02 00:00:00    25.0      0.86      0.85      0.86   0.860138
# 26  2019-08-03 00:00:00    22.0      0.85      0.85      0.85   0.853379
# 27  2019-08-04 00:00:00    27.0      0.85      0.84      0.84   0.844460
# 28  2019-08-05 00:00:00    71.0      0.89      0.84      0.87   0.861487
# 29  2019-08-06 00:00:00    23.0      0.89      0.88      0.89   0.880496
# 30  2019-08-07 00:00:00    26.0      0.89      0.89      0.89   0.886832
# 31  2019-08-08 00:00:00    17.0      0.90      0.89      0.90   0.895611
# 32  2019-08-09 00:00:00    24.0      0.90      0.89      0.89   0.891870
# 33  2019-08-10 00:00:00    17.0      0.89      0.88      0.89   0.890623
# 34  2019-08-11 00:00:00    25.0      0.90      0.88      0.89   0.890208
# 35  2019-08-12 00:00:00     0.5      0.89      0.89      0.89   0.890069
#
#     slow_ewma     EWMAC  EWMAC_rounded  volatility  EWMAC_%_price position  \
# 0    0.870000  0.000000           0.00         NaN       0.000000    Short
# 1    0.870000  0.000000           0.00         NaN       0.000000    Short
# 2    0.875625  0.001875           0.00         NaN       0.213068    Short
# 3    0.877461  0.001770           0.00         NaN       0.201094    Short
# 4    0.878351  0.001399           0.00       0.876       0.158982    Short
# 5    0.878863  0.001054           0.00       0.878       0.119788    Short
# 6    0.879188  0.000785           0.00       0.880       0.089190    Short
# 7    0.879406  0.000585           0.00       0.880       0.066491    Short
# 8    0.887256  0.012744           0.01       0.886       1.400470     Long
# 9    0.897859  0.022142           0.02       0.896       2.380876     Long
# 10   0.910467  0.029533           0.03       0.910       3.108784     Long
# 11   0.922215  0.031119           0.03       0.926       3.241553     Long
# 12   0.931044  0.026734           0.03       0.942       2.784763     Long
# 13   0.935424  0.017169           0.02       0.950       1.807276     Long
# 14   0.938762  0.012103           0.01       0.954       1.273949     Long
# 15   0.941318  0.008970           0.01       0.954       0.944214    Short
# 16   0.943283  0.006813           0.01       0.952       0.717203    Short
# 17   0.942543  0.000823           0.00       0.948       0.087503    Short
# 18   0.941972 -0.000850          -0.00       0.946      -0.090400    Short
# 19   0.941530 -0.001156          -0.00       0.944      -0.122954    Short
# 20   0.938951 -0.005493          -0.01       0.940      -0.590606    Short
# 21   0.936951 -0.005799          -0.01       0.936      -0.623519    Short
# 22   0.939863  0.003855           0.00       0.938       0.405781    Short
# 23   0.919831 -0.038592          -0.04       0.920      -4.540249    Short
# 24   0.904276 -0.043863          -0.04       0.902      -5.160331    Short
# 25   0.894418 -0.034281          -0.03       0.888      -3.986127    Short
# 26   0.884533 -0.031154          -0.03       0.872      -3.665181    Short
# 27   0.874626 -0.030166          -0.03       0.850      -3.591196    Short
# 28   0.873597 -0.012110          -0.01       0.854      -1.391994    Short
# 29   0.877245  0.003251           0.00       0.862       0.365278    Short
# 30   0.880081  0.006751           0.01       0.868       0.758566    Short
# 31   0.884509  0.011102           0.01       0.878       1.233516     Long
# 32   0.885730  0.006141           0.01       0.888       0.689957    Short
# 33   0.886679  0.003945           0.00       0.892       0.443213    Short
# 34   0.887417  0.002791           0.00       0.892       0.313574    Short
# 35   0.887991  0.002078           0.00       0.892       0.233504    Short
#
#     change  position_lots  position_money  transaction_costs  \
# 0      NaN            NaN             NaN               0.00
# 1      0.0            NaN             NaN               0.00
# 2      0.0            NaN             NaN               0.00
# 3      0.0            NaN             NaN               0.00
# 4      0.0            NaN             NaN               0.00
# 5      0.0            NaN             NaN               0.00
# 6      0.0            NaN             NaN               0.00
# 7      0.0            NaN             NaN               0.00
# 8      1.0           55.0          -50.05               0.00
# 9      0.0            NaN             NaN               0.00
# 10     0.0            NaN             NaN               0.00
# 11     0.0            NaN             NaN               0.00
# 12     0.0            NaN             NaN               0.00
# 13     0.0            NaN             NaN               0.00
# 14     0.0            NaN             NaN               0.00
# 15    -1.0          -55.0           52.25              -1.10
# 16     0.0            NaN             NaN               0.00
# 17     0.0            NaN             NaN               0.00
# 18     0.0            NaN             NaN               0.00
# 19     0.0            NaN             NaN               0.00
# 20     0.0            NaN             NaN               0.00
# 21     0.0            NaN             NaN               0.00
# 22     0.0            NaN             NaN               0.00
# 23     0.0            NaN             NaN               0.00
# 24     0.0            NaN             NaN               0.00
# 25     0.0            NaN             NaN               0.00
# 26     0.0            NaN             NaN               0.00
# 27     0.0            NaN             NaN               0.00
# 28     0.0            NaN             NaN               0.00
# 29     0.0            NaN             NaN               0.00
# 30     0.0            NaN             NaN               0.00
# 31     1.0           56.0          -50.40               0.00
# 32    -1.0          -56.0           49.84              -1.12
# 33     0.0            NaN             NaN               0.00
# 34     0.0            NaN             NaN               0.00
# 35     0.0            NaN             NaN               0.00
#
#     position_money_final
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                 -50.05
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                 51.15
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# 30                   NaN
# 31                -50.40
# 32                 48.72
# 33                   NaN
# 34                   NaN
# 35                   NaN
